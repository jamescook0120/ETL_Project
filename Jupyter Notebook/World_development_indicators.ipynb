# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
csv= '../Resources/world_development_indicators.csv'
World_dev= pd.read_csv(csv)
World_dev.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
World_dev= World_dev[['CountryCode','TableName','CurrencyUnit','Region','IncomeGroup']]
World_dev.head()
# Out:
#   CountryCode       TableName    CurrencyUnit                      Region  \
# 0         AFG     Afghanistan  Afghan afghani                  South Asia
# 1         ALB         Albania    Albanian lek       Europe & Central Asia
# 2         DZA         Algeria  Algerian dinar  Middle East & North Africa
# 3         ASM  American Samoa     U.S. dollar         East Asia & Pacific
# 4         ADO         Andorra            Euro       Europe & Central Asia
#
#             IncomeGroup
# 0            Low income
# 1   Upper middle income
# 2   Upper middle income
# 3   Upper middle income
# 4  High income: nonOECD

# %%
World_dev= World_dev.rename(columns={'TableName': 'country', 'IncomeGroup': 'developed_incomegroup'})

# %%
World_dev.head()
# Out:
#   CountryCode         country    CurrencyUnit                      Region  \
# 0         AFG     Afghanistan  Afghan afghani                  South Asia
# 1         ALB         Albania    Albanian lek       Europe & Central Asia
# 2         DZA         Algeria  Algerian dinar  Middle East & North Africa
# 3         ASM  American Samoa     U.S. dollar         East Asia & Pacific
# 4         ADO         Andorra            Euro       Europe & Central Asia
#
#   developed_incomegroup
# 0            Low income
# 1   Upper middle income
# 2   Upper middle income
# 3   Upper middle income
# 4  High income: nonOECD

# %%
World_dev=World_dev.sort_values(by='CountryCode', ascending=True)

# %%
World_dev
# Out:
#     CountryCode           country        CurrencyUnit  \
# 10          ABW             Aruba       Aruban florin
# 4           ADO           Andorra                Euro
# 0           AFG       Afghanistan      Afghan afghani
# 5           AGO            Angola      Angolan kwanza
# 1           ALB           Albania        Albanian lek
# ..          ...               ...                 ...
# 244         YEM       Yemen, Rep.         Yemeni rial
# 199         ZAF      South Africa  South African rand
# 54          ZAR  Congo, Dem. Rep.     Congolese franc
# 245         ZMB            Zambia  New Zambian kwacha
# 246         ZWE          Zimbabwe         U.S. dollar
#
#                          Region developed_incomegroup
# 10    Latin America & Caribbean  High income: nonOECD
# 4         Europe & Central Asia  High income: nonOECD
# 0                    South Asia            Low income
# 5            Sub-Saharan Africa   Upper middle income
# ...

# %%
connect = "postgres:postgres@localhost:5432/happiness_db"
engine = create_engine(f'postgresql://{connect}')

# %%
engine.table_names()
# Out:
# ['world_happiness_2021', 'forbes_billionaires']

# %%
World_dev.to_sql(name='world_development_indicators', con=engine, if_exists='append', index=False)
